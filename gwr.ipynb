# %%
import numpy as np
import libpysal as ps
from mgwr.gwr import GWR, MGWR
from mgwr.sel_bw import Sel_BW
import geopandas as gp
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

inputPath=''

# %%
#Load Shapefile
# georgia_data = pd.read_csv(ps.examples.get_path('GData_utm.csv'))
print(inputPath+'wilayahStudiHeksagon2.shp')
wilayahStudiSHP = gp.read_file(inputPath+'wilayahStudiHeksagon2.shp')
fig, ax = plt.subplots(figsize=(10,10))
wilayahStudiSHP.plot(ax=ax, **{'edgecolor':'black', 'facecolor':'white'})
wilayahStudiSHP.centroid.plot(ax=ax, c='black')
# Out:
# /Users/kuni/Documents/MPWK/Semester IV/Tesis/data/shapefile/wilayahStudiHeksagon2.shp
# <Axes: >

# %%
import os
Y_SHP=gp.read_file(inputPath+'variabel_y/rasio_penyakit.shp')
x_list = os.listdir(inputPath+'variabel_x')
print(x_list)
for x in x_list:
    if x.endswith(".txt"):
        # Prints only text file present in My Folder
        print(x)
# Out:
# ['countRekreasi.dbf', 'jarakSaranaKesehatan.prj', 'luasTutupanLahan.dbf', 'countRekreasi.qix', 'countTempatBekerja.prj', 'indeksEntropy.prj', 'countPerbelanjaan.prj', 'IntersectionDensity.prj', 'risikoBanjir.dbf', 'risikoBanjir.shp', 'risikoBanjir.cpg', 'countPendidikan.prj', 'risikoBanjir.shx', 'risikoBanjir.qmd', 'TitikTempatBekerja.prj', 'kekompakkan.prj', 'countRekreasi.shx', 'countRekreasi.qmd', 'luasTutupanLahan.shp', 'luasTutupanLahan.cpg', 'countRekreasi.shp', 'countRekreasi.cpg', 'luasTutupanLahan.shx', 'luasTutupanLahan.qmd', 'countTempatBekerja.shx', 'jarakSaranaKesehatan.cpg', 'countTempatBekerja.qmd', 'jarakSaranaKesehatan.shp', 'jarakSaranaKesehatan.qmd', 'countTempatBekerja.shp', 'jarakSaranaKesehatan.shx', 'countTempatBekerja.cpg', 'TitikTempatBekerja.dbf', 'kekompakkan.dbf', 'IntersectionDensity.shx', 'IntersectionDensity.qmd', 'indeksEntropy.shp', 'indeksEntropy.cpg', 'countPerbelanjaan.shp', 'countPerbelanjaan.cpg', 'countPendidikan.dbf', 'IntersectionDensity.shp',
# ...
